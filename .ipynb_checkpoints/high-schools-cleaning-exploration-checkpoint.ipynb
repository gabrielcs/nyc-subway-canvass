# %%
# https://data.cityofnewyork.us/Education/DOE-High-School-Directory-2017/s3k6-pzi2

import pandas as pd

all_high_schools = pd.read_csv('data/DOE_High_School_Directory_2017.csv')
all_high_schools.shape
# Out:
# (440, 453)

# %%
pd.set_option('display.max_columns', 453)
all_high_schools.head(3)
# Out:
#       dbn                        school_name boro  \
# 0  31R455            Tottenville High School    R
# 1  30Q450       Long Island City High School    Q
# 2  30Q445  William Cullen Bryant High School    Q
#
#                                   overview_paragraph  school_10th_seats  \
# 0  Tottenville High School has long been recogniz...                1.0
# 1  Our academically and aesthetically enriched pr...                1.0
# 2  Our school is dedicated to ensuring that all s...                1.0
#
#                               academicopportunities1  \
# 0   Institute Programs: Science, Classics/Humanities
# 1         CTE program(s) in: Hospitality and Tourism
# 2  CTE program(s) in: Business, Management & Admi...
#
#                               academicopportunities2  \
# 0                     Honors Program for grades 9-12
# 1  iLearnNYC: Program for expanded online coursew...
# 2  iLearnNYC: Program for expanded online coursew...
#
# ...

# %%
boys_only = all_high_schools['boys'] == 1
columns_of_interest = ['dbn', 'school_name', 'boro', 'academicopportunities1', 'academicopportunities2', 
                       'academicopportunities3', 'academicopportunities4', 'academicopportunities5',
                       'neighborhood', 'location', 'subway', 'bus', 'total_students', 'start_time', 'end_time',
                       'graduation_rate', 'attendance_rate', 'pct_stu_enough_variety', 'college_career_rate', 
                       'girls', 'specialized', 'earlycollege', 'program1', 'program2', 'program3', 'program4', 
                       'program5', 'program6', 'program7', 'program8', 'program9', 'program10', 'interest1',
                       'interest2', 'interest3', 'interest4', 'interest5', 'interest6', 'interest7', 'interest8', 
                       'interest9', 'interest10', 'city', 'zip']
df = all_high_schools[~boys_only][columns_of_interest]
df.set_index('dbn', inplace=True)
df.shape
# Out:
# (436, 43)

# %%
df.head(3)
# Out:
#                               school_name boro  \
# dbn
# 31R455            Tottenville High School    R
# 30Q450       Long Island City High School    Q
# 30Q445  William Cullen Bryant High School    Q
#
#                                    academicopportunities1  \
# dbn
# 31R455   Institute Programs: Science, Classics/Humanities
# 30Q450         CTE program(s) in: Hospitality and Tourism
# 30Q445  CTE program(s) in: Business, Management & Admi...
#
#                                    academicopportunities2  \
# dbn
# 31R455                     Honors Program for grades 9-12
# 30Q450  iLearnNYC: Program for expanded online coursew...
# 30Q445  iLearnNYC: Program for expanded online coursew...
#
#                                    academicopportunities3  \
# dbn
# 31R455                                       ROTC Program
# 30Q450  Eight Small Learning Communities: Culinary; Re...
# 30Q445  Accounting, Entrepreneurship and Marketing, Ar...
#
# ...

# %%
import numpy as np

def contains_terms(column_name, terms=["tech"]):
    contains = []
    for i, term in enumerate(terms):
        contains.append(df[column_name].str.contains(terms[i], case=False))

    not_null = df[column_name].notnull()
    return (not_null) & (np.any(contains, axis=0))
    

def contains_terms_columns(column_root, n_columns, terms=["tech"]):
    if n_columns == 1:
        return contains_terms(column_root, terms)
    
    tech = []
    for i in range(n_columns):
        column_name = column_root + str(i + 1)
        tech.append(contains_terms(column_name, terms))
    
    return np.any(tech, axis=0)

# %%
tech_academicopportunities = contains_terms_columns('academicopportunities', 5, 
                                                    terms=['technology', 'computer', 'web', 'programming', 'coding'])
len(df[tech_academicopportunities])
# Out:
# 177

# %%
# searching for 'tech' might match the word 'technical' 
all_tech_program = contains_terms_columns('program', 10, terms=['programming', 'computer', 'tech'])
technical_program = contains_terms_columns('program', 10, terms=['technical'])
tech_program = (all_tech_program) & ~(technical_program)
len(df[tech_program])
# Out:
# 71

# %%
tech_interest = contains_terms_columns('interest', 10, terms=['computer', 'technology'])
len(df[tech_interest])
# Out:
# 43

# %%
tech_inclined = (tech_academicopportunities) | (tech_program) | (tech_interest)
print(len(df[tech_inclined]))
print("{:.1f}%".format(100 * len(df[tech_inclined]) / len(df)))
# Out:
# 200
# 45.9%

# %%
df['tech_academicopportunities'] = tech_academicopportunities.astype(int)
df['tech_program'] = tech_program.astype(int)
df['tech_interest'] = tech_interest.astype(int)
df.head(3)
# Out:
#                               school_name boro  \
# dbn
# 31R455            Tottenville High School    R
# 30Q450       Long Island City High School    Q
# 30Q445  William Cullen Bryant High School    Q
#
#                                    academicopportunities1  \
# dbn
# 31R455   Institute Programs: Science, Classics/Humanities
# 30Q450         CTE program(s) in: Hospitality and Tourism
# 30Q445  CTE program(s) in: Business, Management & Admi...
#
#                                    academicopportunities2  \
# dbn
# 31R455                     Honors Program for grades 9-12
# 30Q450  iLearnNYC: Program for expanded online coursew...
# 30Q445  iLearnNYC: Program for expanded online coursew...
#
#                                    academicopportunities3  \
# dbn
# 31R455                                       ROTC Program
# 30Q450  Eight Small Learning Communities: Culinary; Re...
# 30Q445  Accounting, Entrepreneurship and Marketing, Ar...
#
# ...

# %%
new_columns = ['school_name', 'boro', 'tech_academicopportunities', 'neighborhood', 'location', 'subway', 
               'bus', 'total_students', 'start_time', 'end_time', 'graduation_rate', 'attendance_rate', 
               'pct_stu_enough_variety', 'college_career_rate', 'girls', 'specialized', 'earlycollege',
               'tech_program', 'tech_interest', 'city', 'zip']
tech_schools = df[tech_inclined][new_columns]
tech_schools.head(3)
# Out:
#                                          school_name boro  \
# dbn
# 30Q450                  Long Island City High School    Q
# 30Q445             William Cullen Bryant High School    Q
# 30Q501  Frank Sinatra School of the Arts High School    Q
#
#         tech_academicopportunities neighborhood  \
# dbn
# 30Q450                           1      Astoria
# 30Q445                           0      Astoria
# 30Q501                           1      Astoria
#
#                                                  location  \
# dbn
# 30Q450  14-30 Broadway, Astoria NY 11106 (40.765881, -...
# 30Q445  48-10 31st Avenue, Astoria NY 11103 (40.757072...
# 30Q501  35-12 35th Avenue, Astoria NY 11106 (40.756099...
#
#                                                    subway  \
# dbn
# 30Q450                                   N, Q to Broadway
# 30Q445                                    M, R to 46th St
# 30Q501  M, R to Steinway St ; N, Q to 36 Ave-Washingto...
#
# ...

# %%
potential = tech_schools['college_career_rate'] * tech_schools['college_career_rate']
potential.sort_values(inplace=True, ascending=False)
potential
# Out:
# dbn
# 25Q525    1.000000
# 10X445    0.978121
# 13K430    0.925444
# 30Q501    0.917764
# 02M416    0.908209
# 28Q687    0.883600
# 04M610    0.879844
# 31R605    0.828100
# 02M411    0.822649
# 27Q323    0.820836
# 30Q286    0.804609
# 04M555    0.802816
# 24Q610    0.746496
# 03M485    0.715716
# 13K595    0.678976
# 01M539    0.677329
# 25Q285    0.677329
# 02M519    0.667489
# 02M412    0.656100
# 17K543    0.640000
# 22K405    0.635209
# 25Q281    0.632025
# 13K483    0.630436
# 04M435    0.617796
# 18K563    0.617796
# 27Q650    0.600625
# 20K485    0.595984
# 26Q495    0.594441
# 14K561    0.586756
# 07X495    0.585225
#             ...
# 04M409    0.046656
# 19K504    0.044100
# 26Q315         NaN
# 10X524         NaN
# 10X565         NaN
# 10X264         NaN
# 19K422         NaN
# 11X509         NaN
# 11X508         NaN
# 29Q313         NaN
# 08X561         NaN
# 02M422         NaN
# 02M282         NaN
# 02M280         NaN
# 02M135         NaN
# 02M507         NaN
# ...

# %%
null_college_career_rate = tech_schools.college_career_rate.isnull()
print("{:.1f}%".format(100 * len(tech_schools[null_college_career_rate]) / len(tech_schools)))
# Out:
# 14.0%

# %%
null_graduation_rate = tech_schools.graduation_rate.isnull()
print("{:.1f}%".format(100 * len(tech_schools[null_graduation_rate]) / len(tech_schools)))
# Out:
# 11.0%

# %%
print("{:.1f}%".format(100 * len(tech_schools[(null_college_career_rate) & \
                                              (null_graduation_rate)]) \
                       / len(tech_schools)))
# Out:
# 11.0%

# %%
tech_schools['total_students'].hist(bins=range(0, 6000, 250), figsize=(12, 5))

# %%
tech_schools[(null_college_career_rate) & (null_graduation_rate)]['total_students'].max()
# Out:
# 662

# %%
# %matplotlib inline
import pylab as pl

ax = tech_schools['college_career_rate'].hist()
ax.set_xlabel('College Career Rate')
ax.set_ylabel('Number of Schools with that Rate')
pl.suptitle('Number of Schools by College Career Rate')

fig = ax.get_figure()
fig.savefig('figures/college-career-rate.png', bbox_inches='tight')

# %%
pd.options.mode.chained_assignment = None

tech_college_potential = tech_schools.dropna(subset=['college_career_rate'])
tech_college_potential['potential_college_students'] = (tech_college_potential['total_students'] * \
                                                        tech_college_potential['college_career_rate']).astype(int)

tech_college_potential.sort_values('potential_college_students', inplace=True, ascending=False)
tech_college_potential.head(3)
# Out:
#                            school_name boro  tech_academicopportunities  \
# dbn
# 13K430  Brooklyn Technical High School    K                           1
# 22K405             Midwood High School    K                           1
# 10X445    Bronx High School of Science    X                           1
#
#                  neighborhood  \
# dbn
# 13K430            Fort Greene
# 22K405               Flatbush
# 10X445  Van Cortlandt Village
#
#                                                  location  \
# dbn
# 13K430  29 Ft Greene Place, Brooklyn NY 11217 (40.6888...
# 22K405  2839 Bedford Avenue, Brooklyn NY 11210 (40.632...
# 10X445  75 West 205th Street, Bronx NY 10468 (40.87995...
#
#                                                    subway  \
# dbn
# 13K430  D, N to Atlantic Ave  Barclays Center; G to F...
# 22K405          2, 5 to Flatbush Ave    Brooklyn College
# 10X445  4 to Bedford Park Blvd - Lehman College ; B, D...
#
# ...

# %%
ax = tech_college_potential['potential_college_students'].hist(bins=range(0, 6000, 250), 
                                                          figsize=(12, 5))
ax.set_xlabel('Potential College Students')
ax.set_ylabel('Number of Schools')
pl.suptitle('Number of Schools by Potential College Students')

fig = ax.get_figure()
fig.savefig('figures/potential-college-students.png', bbox_inches='tight')

# %%
high_potential = tech_college_potential['potential_college_students'] > 1000
high_potential_schools = tech_college_potential[high_potential]
len(high_potential_schools)
# Out:
# 24

# %%
high_potential_schools.loc[:, ('subway', 'bus')]
# Out:
#                                                    subway  \
# dbn
# 13K430  D, N to Atlantic Ave  Barclays Center; G to F...
# 22K405          2, 5 to Flatbush Ave    Brooklyn College
# 10X445  4 to Bedford Park Blvd - Lehman College ; B, D...
# 21K525                                         Q to Ave M
# 26Q495                                                NaN
# 31R460                                                NaN
# 03M485  1 to 66th St - Lincoln Center ; 2, A, B, C, D ...
# 22K425                                                NaN
# 28Q505  E, J, Z to Jamaica Center - Parsons / Archer ;...
# 20K445                                       D to 79th St
# 25Q425                                                NaN
# 24Q610                                       7 to 33rd St
# 31R440                                                NaN
# 20K505           F to Bay Parkway-22nd Ave; N to 20th Ave
# 28Q620                                      F to 169th St
# ...

# %%
close_to_subway = high_potential_schools.dropna(subset=['subway'])
close_to_subway
# Out:
#                                               school_name boro  \
# dbn
# 13K430                     Brooklyn Technical High School    K
# 22K405                                Midwood High School    K
# 10X445                       Bronx High School of Science    X
# 21K525                       Edward R. Murrow High School    K
# 03M485  Fiorello H. LaGuardia High School of Music & A...    M
# 28Q505                              Hillcrest High School    Q
# 20K445                            New Utrecht High School    K
# 24Q610  Aviation Career & Technical Education High School    Q
# 20K505              Franklin Delano Roosevelt High School    K
# 28Q620  Thomas A. Edison Career and Technical Educatio...    Q
# 01M539  New Explorations into Science, Technology and ...    M
# 21K540                             John Dewey High School    K
# 31R450                                 Curtis High School    R
# 30Q445                  William Cullen Bryant High School    Q
# ...

# %%
def add_coord_columns(dataframe, condensed_column, sep=', '):
    coord_str = dataframe.apply(lambda x: x[condensed_column][x[condensed_column].find("(") + 1 : \
                                                              x[condensed_column].find(")")], \
                                axis='columns')

    dataframe['latitude'] = coord_str.apply(lambda x: x[ : x.find(sep)]).astype(float)
    dataframe['longitude'] = coord_str.apply(lambda x: x[x.find(sep) + 1 : ]).astype(float)

# %%
add_coord_columns(close_to_subway, 'location')
close_to_subway.loc[:, ('latitude', 'longitude')]
# Out:
#          latitude  longitude
# dbn
# 13K430  40.688896 -73.976435
# 22K405  40.632829 -73.952356
# 10X445  40.879958 -73.889011
# 21K525  40.619671 -73.959141
# 03M485  40.774202 -73.985976
# 28Q505  40.709461 -73.803001
# 20K445  40.613041 -74.002308
# 24Q610  40.743309 -73.929577
# 20K505  40.621299 -73.982583
# 28Q620  40.716071 -73.799692
# 01M539  40.719416 -73.979581
# 21K540  40.588070 -73.981925
# 31R450  40.645436 -74.082149
# 30Q445  40.757072 -73.911165
# 27Q323  40.584543 -73.825162
# 31R605  40.568299 -74.117086
# 21K410  40.582627 -73.968733

# %%
close_to_subway.rename(columns={'subway': 'subway_lines'}, inplace=True)

df_to_pickle = close_to_subway.loc[:, ('school_name', 'potential_college_students', 'latitude', 'longitude', 
                                    'start_time', 'end_time', 'subway_lines', 'city')]
df_to_pickle
# Out:
#                                               school_name  \
# dbn
# 13K430                     Brooklyn Technical High School
# 22K405                                Midwood High School
# 10X445                       Bronx High School of Science
# 21K525                       Edward R. Murrow High School
# 03M485  Fiorello H. LaGuardia High School of Music & A...
# 28Q505                              Hillcrest High School
# 20K445                            New Utrecht High School
# 24Q610  Aviation Career & Technical Education High School
# 20K505              Franklin Delano Roosevelt High School
# 28Q620  Thomas A. Edison Career and Technical Educatio...
# 01M539  New Explorations into Science, Technology and ...
# 21K540                             John Dewey High School
# 31R450                                 Curtis High School
# 30Q445                  William Cullen Bryant High School
# 27Q323                                  Scholars' Academy
# ...

# %%
df_to_pickle.to_pickle('pickle/high_schools.p')
